# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import palettable (it does not work...)

sys.path.append('../../src/write_entities/')
sys.path.append('../../src/util/')

from define_exposures import call_exposures
# Out:
# 2020-07-20 11:07:38,648 - climada - DEBUG - Loading default config file: C:\Users\valen\Documents\GitHub\climada_python\climada\conf\defaults.conf

# %%
exposures = call_exposures()
# Out:
# 2020-07-20 11:07:42,173 - climada.util.coordinates - INFO - Setting geometry points.
# 2020-07-20 11:07:54,131 - climada.entity.exposures.base - INFO - tag metadata set to default value:  File:
#  Description:
# 2020-07-20 11:07:54,132 - climada.entity.exposures.base - INFO - ref_year metadata set to default value: 2018
# 2020-07-20 11:07:54,132 - climada.entity.exposures.base - INFO - meta metadata set to default value: None
# 2020-07-20 11:07:54,133 - climada.entity.exposures.base - INFO - centr_ not set.
# 2020-07-20 11:07:54,133 - climada.entity.exposures.base - INFO - deductible not set.
# 2020-07-20 11:07:54,135 - climada.entity.exposures.base - INFO - cover not set.
# 2020-07-20 11:07:54,135 - climada.entity.exposures.base - INFO - category_id not set.
# 2020-07-20 11:07:54,135 - climada.entity.exposures.base - INFO - region_id not set.
# 2020-07-20 11:08:06,223 - climada.entity.exposures.base - INFO - Setting latitude and longitude attributes.
# ...

# %%
exposures['Under 75 years'].plot_hexbin(bins = 'log',pop_name=False,cmap='PuRd')
#plt.savefig('../figures/map_exposures_ch_under75.pdf',bbox_inches='tight')
# Out:
# C:\Users\valen\Documents\GitHub\climada_python\climada\util\plot.py:311: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# C:\Users\valen\.conda\envs\climada_env\lib\site-packages\cartopy\mpl\feature_artist.py:225: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   **dict(style))
# C:\Users\valen\.conda\envs\climada_env\lib\site-packages\cartopy\mpl\feature_artist.py:225: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   **dict(style))

# %%
exposures['Over 75 years'].plot_hexbin(bins = 'log',pop_name=False,cmap='PuRd')
#plt.savefig('../figures/health/map_exposures_ch_over75.pdf',bbox_inches='tight')
# Out:
# C:\Users\valen\Documents\GitHub\climada_python\climada\util\plot.py:311: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
# C:\Users\valen\.conda\envs\climada_env\lib\site-packages\cartopy\mpl\feature_artist.py:225: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   **dict(style))
